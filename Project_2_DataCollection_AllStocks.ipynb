# %%
# Import all the required libraries
import pandas as pd
import pandas_datareader
from pandas_datareader import data
# import numpy as np
import datetime
import yfinance as yf
from path import Path

# %%
# set the tickers
tickers = ["BMO.TO", "TRI.TO", "L.TO", "CIX.TO"]

# extract data from 01/01/2019 to 03/03/2022.
start_date = datetime.date(2019,1,1)
end_date = datetime.date(2022,3,3)

# %%
# Use data.DataReader to load the data
panel_data = data.DataReader(tickers, "yahoo", start_date, end_date)

# Checkout the data type
type(panel_data)
# Out:
# pandas.core.frame.DataFrame

# %%
# checkout the data
panel_data
# Out:
# Attributes   Adj Close                                          Close  \
# Symbols         BMO.TO      TRI.TO        L.TO     CIX.TO      BMO.TO
# Date
# 2019-01-02   78.031769   61.395039   57.818459  15.299248   89.559998
# 2019-01-03   77.317322   60.093006   57.458565  15.451078   88.739998
# 2019-01-04   78.545822   60.558704   57.581684  15.486806   90.150002
# 2019-01-07   78.354141   60.007481   58.121513  15.611843   89.930000
# 2019-01-08   79.051163   60.054993   58.576103  15.745808   90.730003
# ...                ...         ...         ...        ...         ...
# 2022-02-25  145.270004  128.440002  100.949997  20.930000  145.270004
# 2022-02-28  144.729996  128.160004   98.870003  20.750000  144.729996
# 2022-03-01  144.669998  129.940002   98.019997  20.410000  144.669998
# 2022-03-02  147.639999  131.190002   99.489998  20.969999  147.639999
# 2022-03-03  147.779999  132.139999  102.199997  21.379999  147.779999
#
# Attributes                                           High              ...  \
# Symbols         TRI.TO        L.TO     CIX.TO      BMO.TO      TRI.TO  ...
# Date                                                                   ...
# 2019-01-02   64.599998   61.049999  17.129999   89.559998   65.730003  ...
# 2019-01-03   63.230000   60.669998  17.299999   89.430000   64.599998  ...
# 2019-01-04   63.720001   60.799999  17.340000   90.290001   64.050003  ...
# 2019-01-07   63.139999   61.369999  17.480000   90.410004   63.709999  ...
# 2019-01-08   63.189999   61.849998  17.629999   90.750000   64.139999  ...
# ...                ...         ...        ...         ...         ...  ...
# 2022-02-25  128.440002  100.949997  20.930000  146.399994  129.210007  ...
# 2022-02-28  128.160004   98.870003  20.750000  144.759995  128.360001  ...
# 2022-03-01  129.940002   98.019997  20.410000  147.649994  130.229996  ...
# 2022-03-02  131.190002   99.489998  20.969999  148.850006  131.690002  ...
# 2022-03-03  132.139999  102.199997  21.379999  148.729996  133.009995  ...
#
# Attributes        Low                   Open                         \
# Symbols          L.TO     CIX.TO      BMO.TO      TRI.TO       L.TO
# Date
# 2019-01-02  60.450001  16.920000   88.580002   65.730003  60.970001
# 2019-01-03  60.369999  16.930000   89.379997   64.389999  60.770000
# 2019-01-04  60.509998  17.280001   89.680000   63.599998  60.930000
# 2019-01-07  60.470001  17.200001   90.410004   63.680000  61.000000
# 2019-01-08  61.310001  17.450001   90.500000   63.439999  61.549999
# ...               ...        ...         ...         ...        ...
# 2022-02-25  97.370003  20.450001  143.600006  129.009995  99.570000
# 2022-02-28  98.449997  20.420000  143.289993  127.610001  99.919998
# 2022-03-01  97.650002  20.219999  146.479996  128.100006  98.839996
# 2022-03-02  98.019997  20.420000  146.070007  130.179993  98.129997
# 2022-03-03  99.580002  20.879999  148.270004  131.839996  99.580002
#
# Attributes                Volume
# Symbols        CIX.TO     BMO.TO     TRI.TO       L.TO     CIX.TO
# Date
# 2019-01-02  17.129999  1702600.0  1058300.0   626700.0   379300.0
# 2019-01-03  17.100000  1103200.0   870000.0   617800.0   575100.0
# 2019-01-04  17.510000  1239200.0   791600.0   444100.0   526900.0
# 2019-01-07  17.389999  2532100.0   854000.0   724700.0   382500.0
# 2019-01-08  17.610001  1905900.0  1162800.0   601100.0   384800.0
# ...               ...        ...        ...        ...        ...
# 2022-02-25  20.680000  1866000.0   288000.0   810300.0   710700.0
# 2022-02-28  20.700001  2571000.0   716100.0  1081900.0  1152000.0
# 2022-03-01  20.850000  2483500.0   389300.0   497200.0   878300.0
# 2022-03-02  20.420000  1767100.0   391300.0   439000.0   825700.0
# 2022-03-03  21.000000  1767100.0   331800.0   556800.0   984900.0
#
# [796 rows x 24 columns]

# %%
# filter the data for closing price and volume
closeprice_and_volume = panel_data[["Close", "Volume"]]
closeprice_and_volume.head()
# Out:
# Attributes      Close                                      Volume             \
# Symbols        BMO.TO     TRI.TO       L.TO     CIX.TO     BMO.TO     TRI.TO
# Date
# 2019-01-02  89.559998  64.599998  61.049999  17.129999  1702600.0  1058300.0
# 2019-01-03  88.739998  63.230000  60.669998  17.299999  1103200.0   870000.0
# 2019-01-04  90.150002  63.720001  60.799999  17.340000  1239200.0   791600.0
# 2019-01-07  89.930000  63.139999  61.369999  17.480000  2532100.0   854000.0
# 2019-01-08  90.730003  63.189999  61.849998  17.629999  1905900.0  1162800.0
#
# Attributes
# Symbols         L.TO    CIX.TO
# Date
# 2019-01-02  626700.0  379300.0
# 2019-01-03  617800.0  575100.0
# 2019-01-04  444100.0  526900.0
# 2019-01-07  724700.0  382500.0
# 2019-01-08  601100.0  384800.0

# %%
# get info about the data
closeprice_and_volume.describe()
# Out:
# Attributes       Close                                            Volume  \
# Symbols         BMO.TO      TRI.TO        L.TO      CIX.TO        BMO.TO
# count       796.000000  796.000000  796.000000  796.000000  7.960000e+02
# mean        103.322965  105.435364   73.548153   20.247198  2.373227e+06
# std          21.494046   22.465576   10.982271    3.692122  1.470438e+06
# min          56.240002   63.139999   59.470001   11.170000  2.157000e+05
# 25%          92.329998   89.377499   66.669998   17.787501  1.333775e+06
# 50%         100.349998  101.789997   69.619999   19.265000  1.883300e+06
# 75%         121.639997  116.510002   74.892498   22.545001  3.045475e+06
# max         151.610001  156.009995  104.419998   30.400000  1.160970e+07
#
# Attributes
# Symbols           TRI.TO          L.TO        CIX.TO
# count       7.960000e+02  7.960000e+02  7.960000e+02
# mean        4.807487e+05  5.958864e+05  7.017986e+05
# std         2.905946e+05  3.468558e+05  7.637393e+05
# min         4.660000e+04  1.029000e+05  5.170000e+04
# 25%         3.074750e+05  3.763000e+05  3.977250e+05
# 50%         4.041500e+05  5.082500e+05  5.700500e+05
# 75%         5.661500e+05  7.120750e+05  8.138750e+05
# max         3.020100e+06  3.783900e+06  1.814350e+07

# %%
# Check the data type 
closeprice_and_volume.dtypes
# Out:
# Attributes  Symbols
# Close       BMO.TO     float64
#             TRI.TO     float64
#             L.TO       float64
#             CIX.TO     float64
# Volume      BMO.TO     float64
#             TRI.TO     float64
#             L.TO       float64
#             CIX.TO     float64
# dtype: object

# %%
# Identify frequency of values
closeprice_and_volume.value_counts()
# Out:
# (Close, BMO.TO)  (Close, TRI.TO)  (Close, L.TO)  (Close, CIX.TO)  (Volume, BMO.TO)  (Volume, TRI.TO)  (Volume, L.TO)  (Volume, CIX.TO)
# 56.240002        76.459999        59.700001      11.450000        5328000.0         964900.0          1196400.0       1256600.0           1
# 104.629997       87.480003        69.790001      20.870001        1701600.0         779500.0          730200.0        877100.0            1
# 105.190002       79.800003        65.849998      18.860001        1402200.0         408900.0          350200.0        378300.0            1
# 105.339996       82.000000        65.360001      19.219999        1841600.0         473300.0          293400.0        985200.0            1
# 105.370003       80.540001        64.879997      19.660000        1255300.0         651200.0          653300.0        1075600.0           1
#                                                                                                                                          ..
# 96.919998        88.839996        75.050003      19.379999        985400.0          258700.0          639500.0        272400.0            1
# 96.949997        70.639999        66.629997      17.620001        1021100.0         537700.0          248300.0        1146300.0           1
# 96.970001        87.900002        74.809998      18.910000        1827800.0         285200.0          413800.0        779100.0            1
# 96.980003        69.970001        66.360001      18.120001        1078500.0         334000.0          398600.0        587900.0            1
# 151.610001       132.679993       100.620003     23.309999        2258000.0         561200.0          409900.0        412200.0            1
# Length: 796, dtype: int64

# %%
# Check for null values
closeprice_and_volume.isnull().sum()
# Out:
# Attributes  Symbols
# Close       BMO.TO     0
#             TRI.TO     0
#             L.TO       0
#             CIX.TO     0
# Volume      BMO.TO     0
#             TRI.TO     0
#             L.TO       0
#             CIX.TO     0
# dtype: int64

# %%
# Check for duplicated values
closeprice_and_volume.duplicated().sum()
# Out:
# 0

# %%
# Assign closing price to a separate dataframe
close_price = closeprice_and_volume[["Close"]]
close_price.head()
# Out:
# Attributes      Close
# Symbols        BMO.TO     TRI.TO       L.TO     CIX.TO
# Date
# 2019-01-02  89.559998  64.599998  61.049999  17.129999
# 2019-01-03  88.739998  63.230000  60.669998  17.299999
# 2019-01-04  90.150002  63.720001  60.799999  17.340000
# 2019-01-07  89.930000  63.139999  61.369999  17.480000
# 2019-01-08  90.730003  63.189999  61.849998  17.629999

# %%
# Closing price data visualization
close_price.plot(title = "Closing Price", color=('blue','green','orange', 'brown'), linewidth=3, figsize=(12,6))
# Out:
# <AxesSubplot:title={'center':'Closing Price'}, xlabel='Date'>

# %%
# Assign volume to a separate dataframe
volume = closeprice_and_volume[["Volume"]]
volume.head()
# Out:
# Attributes     Volume
# Symbols        BMO.TO     TRI.TO      L.TO    CIX.TO
# Date
# 2019-01-02  1702600.0  1058300.0  626700.0  379300.0
# 2019-01-03  1103200.0   870000.0  617800.0  575100.0
# 2019-01-04  1239200.0   791600.0  444100.0  526900.0
# 2019-01-07  2532100.0   854000.0  724700.0  382500.0
# 2019-01-08  1905900.0  1162800.0  601100.0  384800.0

# %%
# Volume data visualization
volume.plot(title = "Volume" ,color=('blue','green', 'orange', 'brown' ), linewidth=3, figsize=(12,6))
# Out:
# <AxesSubplot:title={'center':'Volume'}, xlabel='Date'>

# %%
closeprice_and_volume.to_csv('price_and_volume.csv',float_format='%.2f')

# %%
panel_data.to_csv('stock_data.csv',float_format='%.2f')

# %%
# Playing around with yfinance

bmo = yf.Ticker("BMO.TO")
tri = yf.Ticker("TRI.TO")

# %%
bmo.info
# Out:
# {'zip': 'H2Y 1L6',
#  'sector': 'Financial Services',
#  'fullTimeEmployees': 43863,
#  'longBusinessSummary': "Bank of Montreal provides diversified financial services primarily in North America. The company's personal banking products and services include checking and savings accounts, credit cards, mortgages, and financial and investment advice services; and commercial banking products and services comprise business deposit accounts, commercial credit cards, business loans and commercial mortgages, cash management solutions, foreign exchange, specialized banking programs, treasury and payment solutions, and risk management products for small business and commercial banking customers. It also offers investment and wealth advisory services; digital investing services; financial services and solutions; and investment management, and trust and custody services. In addition, the company provides life insurance, accident and sickness insurance, and annuity products; creditor and travel insurance to bank customers; and reinsurance solutions. Further, it offers client's debt and equity capital-raising services, as well as loan origination and syndication, and treasury management; strategic advice on mergers and acquisitions, restructurings, and recapitalizations, as well as valuation and fairness opinions; and trade finance, risk mitigation, and other operating services. Additionally, the company provides research and access to markets for institutional, corporate, and retail clients; trading solutions that include debt, foreign exchange, interest rate, credit, equity, securitization and commodities; new product development and origination services, as well as risk management advice and services to hedge against fluctuations; and funding and liquidity management services to its clients. It operates through approximately 900 bank branches and 3,300 automated banking machines in Canada and the United States. Bank of Montreal was founded in 1817 and is headquartered in Montreal, Canada.",
#  'city': 'Montreal',
#  'state': 'QC',
#  'country': 'Canada',
#  'companyOfficers': [],
#  'website': 'https://www.bmo.com',
#  'maxAge': 1,
#  'address1': '129 rue Saint Jacques',
#  'industry': 'Banks—Diversified',
#  'ebitdaMargins': 0,
#  'profitMargins': 0.30896,
#  'grossMargins': 0,
#  'operatingCashflow': -34588000256,
#  'revenueGrowth': 0.147,
#  'operatingMargins': 0.46240002,
#  'ebitda': None,
#  'targetLowPrice': 143.3,
#  'recommendationKey': 'buy',
#  'grossProfits': 27059000000,
#  'freeCashflow': None,
#  'targetMedianPrice': 169,
#  'currentPrice': 143.02,
#  'earningsGrowth': 0.462,
#  'currentRatio': None,
#  'returnOnAssets': 0.0086900005,
#  'numberOfAnalystOpinions': 13,
#  'targetMeanPrice': 165.48,
#  'debtToEquity': None,
#  'returnOnEquity': 0.14954,
#  'targetHighPrice': 178,
#  'totalCash': 329498001408,
#  'totalDebt': 171442995200,
#  'totalRevenue': 28061999104,
#  'totalCashPerShare': 508.134,
#  'financialCurrency': 'CAD',
#  'revenuePerShare': 43.331,
#  'quickRatio': None,
#  'recommendationMean': 2,
#  'exchange': 'TOR',
#  'shortName': 'BANK OF MONTREAL',
#  'longName': 'Bank of Montreal',
#  'exchangeTimezoneName': 'America/Toronto',
#  'exchangeTimezoneShortName': 'EST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-18000000',
#  'quoteType': 'EQUITY',
#  'symbol': 'BMO.TO',
#  'messageBoardId': 'finmb_19053',
#  'market': 'ca_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': -2.197,
#  'beta3Year': None,
#  'enterpriseToEbitda': None,
#  '52WeekChange': 0.31322074,
#  'morningStarRiskRating': None,
#  'forwardEps': 14.41,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 648478976,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 86.598,
#  'sharesShort': 15769828,
#  'sharesPercentSharesOut': 0.024300002,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1635638400,
#  'heldPercentInstitutions': 0.493,
#  'netIncomeToCommon': 8426999808,
#  'trailingEps': 12.983,
#  'lastDividendValue': 1.33,
#  'SandP52WeekChange': 0.0840292,
#  'priceToBook': 1.6515393,
#  'heldPercentInsiders': 0.00026,
#  'nextFiscalYearEnd': 1698710400,
#  'yield': None,
#  'mostRecentQuarter': 1643587200,
#  'shortRatio': 5.61,
#  'sharesShortPreviousMonthDate': 1643587200,
#  'floatShares': 648258845,
#  'beta': 1.164645,
#  'enterpriseValue': -61664124928,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 983404800,
#  'lastSplitFactor': '2:1',
#  'legalType': None,
#  'lastDividendDate': 1643587200,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.454,
#  'priceToSalesTrailing12Months': 3.3050199,
#  'dateShortInterest': 1646006400,
#  'pegRatio': 1.9,
#  'ytdReturn': None,
#  'forwardPE': 9.925053,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': 15479802,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 142.34,
#  'regularMarketOpen': 142.75,
#  'twoHundredDayAverage': 133.96526,
#  'trailingAnnualDividendYield': 0.0316847,
#  'payoutRatio': 0.3475,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 145.59,
#  'navPrice': None,
#  'averageDailyVolume10Day': 2140720,
#  'regularMarketPreviousClose': 142.34,
#  'fiftyDayAverage': 144.9486,
#  'trailingAnnualDividendRate': 4.51,
#  'open': 142.75,
#  'toCurrency': None,
#  'averageVolume10days': 2140720,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 5.32,
#  'exDividendDate': 1651190400,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 141.13,
#  'currency': 'CAD',
#  'trailingPE': 11.0159445,
#  'regularMarketVolume': 2949639,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 92745465856,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 2472022,
#  'dayLow': 141.13,
#  'ask': 143.02,
#  'askSize': 0,
#  'volume': 2949639,
#  'fiftyTwoWeekHigh': 152.87,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 4.01,
#  'fiftyTwoWeekLow': 107.82,
#  'bid': 142.98,
#  'tradeable': False,
#  'dividendYield': 0.0374,
#  'bidSize': 0,
#  'dayHigh': 145.59,
#  'regularMarketPrice': 143.02,
#  'preMarketPrice': None,
#  'logo_url': 'https://logo.clearbit.com/bmo.com'}

# %%
tri.info
# Out:
# {'zip': 'M5H 2R2',
#  'sector': 'Industrials',
#  'longBusinessSummary': 'Thomson Reuters Corporation provides business information services in the Americas, Europe, the Middle East, Africa, and the Asia Pacific. It operates in five segments: Legal Professionals, Corporates, Tax & Accounting Professionals, Reuters News, and Global Print. The Legal Professionals segment offers research and workflow products focusing on legal research and integrated legal workflow solutions that combine content, tools, and analytics to law firms and governments. The Corporates segment provides a suite of content-enabled technology solutions for legal, tax, regulatory, compliance, and IT professionals. The Tax & Accounting Professionals segment offers research and workflow products focusing on tax offerings and automating tax workflows to tax, accounting, and audit professionals in accounting firms. The Reuters News segment provides business, financial, national, and international news to professionals through desktop terminals, media organizations, and industry events, as well as directly to consumers. The Global Print segment offers legal and tax information primarily in print format to legal and tax professionals, governments, law schools, and corporations. Thomson Reuters Corporation has a strategic alliance with Deloitte Tax LLP to help corporate tax and legal departments enhance global digital transformation. The company was formerly known as The Thomson Corporation and changed its name to Thomson Reuters Corporation in April 2008. The company was founded in 1851 and is headquartered in Toronto, Canada. Thomson Reuters Corporation is a subsidiary of The Woodbridge Company Limited.',
#  'city': 'Toronto',
#  'state': 'ON',
#  'country': 'Canada',
#  'companyOfficers': [],
#  'website': 'https://www.thomsonreuters.com',
#  'maxAge': 1,
#  'address1': '333 Bay Street',
#  'industry': 'Specialty Business Services',
#  'address2': 'Suite 300',
#  'ebitdaMargins': 0.23692,
#  'profitMargins': 0.89619005,
#  'grossMargins': 0.31159002,
#  'operatingCashflow': 1772999936,
#  'revenueGrowth': 0.058,
#  'operatingMargins': 0.1903,
#  'ebitda': 1504000000,
#  'targetLowPrice': 120.78,
#  'recommendationKey': 'hold',
#  'grossProfits': 1978000000,
#  'freeCashflow': 936499968,
#  'targetMedianPrice': 153.81,
#  'currentPrice': 132.02,
#  'earningsGrowth': None,
#  'currentRatio': 0.95,
#  'returnOnAssets': 0.037720002,
#  'numberOfAnalystOpinions': 14,
#  'targetMeanPrice': 150.81,
#  'debtToEquity': 27.367,
#  'returnOnEquity': 0.47762,
#  'targetHighPrice': 171.64,
#  'totalCash': 886000000,
#  'totalDebt': 3785999872,
#  'totalRevenue': 6348000256,
#  'totalCashPerShare': 1.822,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 12.865,
#  'quickRatio': 0.753,
#  'recommendationMean': 2.6,
#  'exchange': 'TOR',
#  'shortName': 'THOMSON REUTERS CORPORATION',
#  'longName': 'Thomson Reuters Corporation',
#  'exchangeTimezoneName': 'America/Toronto',
#  'exchangeTimezoneShortName': 'EST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-18000000',
#  'quoteType': 'EQUITY',
#  'symbol': 'TRI.TO',
#  'messageBoardId': 'finmb_515275',
#  'market': 'ca_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 10.767,
#  'beta3Year': None,
#  'enterpriseToEbitda': 45.444,
#  '52WeekChange': 0.21962488,
#  'morningStarRiskRating': None,
#  'forwardEps': 4.19,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 486200000,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 28.453,
#  'sharesShort': 1807606,
#  'sharesPercentSharesOut': 0.0037,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1640908800,
#  'heldPercentInstitutions': 0.23618001,
#  'netIncomeToCommon': 5685000192,
#  'trailingEps': 14.639,
#  'lastDividendValue': 0.568,
#  'SandP52WeekChange': 0.0840292,
#  'priceToBook': 4.6399326,
#  'heldPercentInsiders': 0.67184997,
#  'nextFiscalYearEnd': 1703980800,
#  'yield': None,
#  'mostRecentQuarter': 1640908800,
#  'shortRatio': 3.87,
#  'sharesShortPreviousMonthDate': 1643587200,
#  'floatShares': 159463876,
#  'beta': 0.317166,
#  'enterpriseValue': 68347383808,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1543276800,
#  'lastSplitFactor': '9079:10000',
#  'legalType': None,
#  'lastDividendDate': 1645574400,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': None,
#  'priceToSalesTrailing12Months': 10.11155,
#  'dateShortInterest': 1646006400,
#  'pegRatio': 1.72,
#  'ytdReturn': None,
#  'forwardPE': 31.508354,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': 1756068,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 134.61,
#  'regularMarketOpen': 134.24,
#  'twoHundredDayAverage': 138.26186,
#  'trailingAnnualDividendYield': 0.012034767,
#  'payoutRatio': 0.1409,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 134.92,
#  'navPrice': None,
#  'averageDailyVolume10Day': 471440,
#  'regularMarketPreviousClose': 134.61,
#  'fiftyDayAverage': 136.1138,
#  'trailingAnnualDividendRate': 1.62,
#  'open': 134.24,
#  'toCurrency': None,
#  'averageVolume10days': 471440,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 2.27,
#  'exDividendDate': 1645574400,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 131.43,
#  'currency': 'CAD',
#  'trailingPE': 9.018376,
#  'regularMarketVolume': 420862,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 64188125184,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 419616,
#  'dayLow': 131.43,
#  'ask': 132.03,
#  'askSize': 0,
#  'volume': 420862,
#  'fiftyTwoWeekHigh': 156.62,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 2.41,
#  'fiftyTwoWeekLow': 107.66,
#  'bid': 132.06,
#  'tradeable': False,
#  'dividendYield': 0.0168,
#  'bidSize': 0,
#  'dayHigh': 134.92,
#  'regularMarketPrice': 132.02,
#  'preMarketPrice': None,
#  'logo_url': 'https://logo.clearbit.com/thomsonreuters.com'}

# %%
bmo_hist = bmo.history(period="max")
bmo_hist.head()
# Out:
#                 Open      High       Low     Close   Volume  Dividends  \
# Date
# 1995-01-12  4.287302  4.287302  4.221821  4.221821   793000        0.0
# 1995-01-13  4.307980  4.307980  4.201142  4.287302  2266600        0.0
# 1995-01-16  4.330381  4.394139  4.330381  4.394139  1591400        0.0
# 1995-01-17  4.351061  4.373463  4.287303  4.351061   900600        0.0
# 1995-01-18  4.351062  4.373464  4.307982  4.373464   898600        0.0
#
#             Stock Splits
# Date
# 1995-01-12           0.0
# 1995-01-13           0.0
# 1995-01-16           0.0
# 1995-01-17           0.0
# 1995-01-18           0.0

# %%
tri_hist = tri.history(period="max")
tri_hist.head()
# Out:
#                  Open       High        Low      Close   Volume  Dividends  \
# Date
# 2008-06-04  23.225970  23.944564  22.937248  23.546770  1380280        0.0
# 2008-06-05  23.739256  23.829080  23.424871  23.508280   814114        0.0
# 2008-06-06  23.482620  23.482620  23.052748  23.225981  1389269        0.0
# 2008-06-09  23.129739  23.335052  22.712698  22.808939   759912        0.0
# 2008-06-10  22.841017  23.059160  22.622871  22.962921   963463        0.0
#
#             Stock Splits
# Date
# 2008-06-04           0.0
# 2008-06-05           0.0
# 2008-06-06           0.0
# 2008-06-09           0.0
# 2008-06-10           0.0

# %%
bmo.actions
# Out:
#             Dividends  Stock Splits
# Date
# 1995-02-02      0.165           0.0
# 1995-05-03      0.165           0.0
# 1995-08-03      0.165           0.0
# 1995-11-06      0.165           0.0
# 1996-02-06      0.180           0.0
# ...               ...           ...
# 2021-01-29      1.060           0.0
# 2021-04-30      1.060           0.0
# 2021-07-30      1.060           0.0
# 2021-10-29      1.060           0.0
# 2022-01-31      1.330           0.0
#
# [110 rows x 2 columns]

# %%
tri.actions
# Out:
#             Dividends  Stock Splits
# Date
# 2008-11-19   0.292984        0.0000
# 2009-05-20   0.385505        0.0000
# 2009-08-19   0.385505        0.0000
# 2009-11-18   0.385505        0.0000
# 2010-03-04   0.337042        0.0000
# 2010-05-18   0.337042        0.0000
# 2010-08-17   0.337042        0.0000
# 2010-11-16   0.337042        0.0000
# 2011-02-17   0.339244        0.0000
# 2011-05-17   0.340346        0.0000
# 2011-08-16   0.340346        0.0000
# 2011-11-15   0.340346        0.0000
# 2012-02-17   0.351360        0.0000
# 2012-05-22   0.348056        0.0000
# 2012-08-21   0.353563        0.0000
# 2012-11-19   0.351360        0.0000
# 2013-02-21   0.359070        0.0000
# 2013-05-21   0.366780        0.0000
# 2013-08-20   0.370085        0.0000
# 2013-11-19   0.373389        0.0000
# 2014-02-20   0.403128        0.0000
# 2014-05-20   0.395418        0.0000
# 2014-08-19   0.395418        0.0000
# 2014-11-18   0.410838        0.0000
# 2015-02-19   0.459302        0.0000
# 2015-05-19   0.448287        0.0000
# 2016-02-19   0.514374        0.0000
# 2016-05-17   0.482432        0.0000
# 2016-08-16   0.483533        0.0000
# 2016-11-15   0.507765        0.0000
# 2017-02-21   0.497852        0.0000
# 2017-08-15   0.483533        0.0000
# 2017-11-15   0.483533        0.0000
# 2018-02-21   0.480229        0.0000
# 2018-05-16   0.489041        0.0000
# 2018-08-15   0.496751        0.0000
# 2018-11-14   5.102985        0.0000
# 2018-11-27   5.898000        0.9079
# 2019-08-21   0.479000        0.0000
# 2019-11-20   0.478000        0.0000
# 2020-03-05   0.509000        0.0000
# 2020-05-20   0.530000        0.0000
# 2020-08-19   0.500000        0.0000
# 2020-11-18   0.498000        0.0000
# 2021-03-04   0.512000        0.0000
# 2021-05-19   0.488000        0.0000
# 2021-08-18   0.511000        0.0000
# 2021-11-17   0.508000        0.0000
# 2022-02-23   0.568000        0.0000

# %%
bmo.financials
# Out:
#                                            2021-10-31     2020-10-31  \
# Research Development                             None           None
# Effect Of Accounting Charges                     None           None
# Income Before Tax                       10258000000.0   6348000000.0
# Minority Interest                                None           None
# Net Income                               7754000000.0   5097000000.0
# Selling General Administrative          12929000000.0  12334000000.0
# Gross Profit                            27059000000.0  22233000000.0
# Ebit                                              0.0            0.0
# Operating Income                        11692000000.0   6981000000.0
# Other Operating Expenses                 2438000000.0   2918000000.0
# Interest Expense                                 None           None
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# Other Items                                      None           None
# Income Tax Expense                       2504000000.0   1251000000.0
# Total Revenue                           27059000000.0  22233000000.0
# Total Operating Expenses                15367000000.0  15252000000.0
# Cost Of Revenue                                   0.0            0.0
# Total Other Income Expense Net          -1434000000.0   -633000000.0
# Discontinued Operations                          None           None
# Net Income From Continuing Ops           7754000000.0   5097000000.0
# Net Income Applicable To Common Shares   7510000000.0   4850000000.0
#
#                                            2019-10-31     2018-10-31
# Research Development                             None           None
# Effect Of Accounting Charges                     None           None
# Income Before Tax                        7272000000.0   7414000000.0
# Minority Interest                                None           None
# Net Income                               5758000000.0   5453000000.0
# Selling General Administrative          12287000000.0  11549000000.0
# Gross Profit                            24611000000.0  22243000000.0
# Ebit                                              0.0            0.0
# Operating Income                         8322000000.0   7917000000.0
# Other Operating Expenses                 4002000000.0   2777000000.0
# Interest Expense                                 None           None
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# Other Items                                      None           None
# Income Tax Expense                       1514000000.0   1961000000.0
# Total Revenue                           24611000000.0  22243000000.0
# Total Operating Expenses                16289000000.0  14326000000.0
# Cost Of Revenue                                   0.0            0.0
# Total Other Income Expense Net          -1050000000.0   -503000000.0
# Discontinued Operations                          None           None
# Net Income From Continuing Ops           5758000000.0   5453000000.0
# Net Income Applicable To Common Shares   5547000000.0   5269000000.0

# %%
tri.financials
# Out:
#                                           2021-12-31    2020-12-31  \
# Research Development                            None          None
# Effect Of Accounting Charges                    None          None
# Income Before Tax                       7294000000.0  1220000000.0
# Minority Interest                               None          None
# Net Income                              5689000000.0  1122000000.0
# Selling General Administrative                   NaN    76000000.0
# Gross Profit                            1978000000.0  2040000000.0
# Ebit                                    1208000000.0  1172000000.0
# Operating Income                        1208000000.0  1172000000.0
# Other Operating Expenses                        None          None
# Interest Expense                        -196000000.0   -82000000.0
# Extraordinary Items                             None          None
# Non Recurring                                   None          None
# Other Items                                     None          None
# Income Tax Expense                      1607000000.0    71000000.0
# Total Revenue                           6348000000.0  5984000000.0
# Total Operating Expenses                5140000000.0  4812000000.0
# Cost Of Revenue                         4370000000.0  3944000000.0
# Total Other Income Expense Net          6086000000.0    48000000.0
# Discontinued Operations                    2000000.0   -27000000.0
# Net Income From Continuing Ops          5687000000.0  1149000000.0
# Net Income Applicable To Common Shares  5687000000.0  1120000000.0
#
#                                           2019-12-31    2018-12-31
# Research Development                            None          None
# Effect Of Accounting Charges                    None          None
# Income Before Tax                        372000000.0   300000000.0
# Minority Interest                               None          None
# Net Income                              1564000000.0  3933000000.0
# Selling General Administrative            97000000.0   146000000.0
# Gross Profit                            1682000000.0  1624000000.0
# Ebit                                     868000000.0   859000000.0
# Operating Income                         868000000.0   859000000.0
# Other Operating Expenses                        None          None
# Interest Expense                        -161000000.0  -330000000.0
# Extraordinary Items                             None          None
# Non Recurring                                   None          None
# Other Items                                     None          None
# Income Tax Expense                     -1198000000.0   136000000.0
# Total Revenue                           5906000000.0  5501000000.0
# Total Operating Expenses                5038000000.0  4642000000.0
# Cost Of Revenue                         4224000000.0  3877000000.0
# Total Other Income Expense Net          -496000000.0  -559000000.0
# Discontinued Operations                   -6000000.0  3859000000.0
# Net Income From Continuing Ops          1570000000.0   164000000.0
# Net Income Applicable To Common Shares  1561000000.0  3930000000.0

# %%
bmo.balance_sheet
# Out:
#                                     2021-10-31    2020-10-31    2019-10-31  \
# Intangible Assets                 2.266000e+09  2.442000e+09  2.424000e+09
# Capital Surplus                   3.130000e+08  3.020000e+08  3.030000e+08
# Total Liab                        9.306520e+11  8.926680e+11  8.011190e+11
# Total Stockholder Equity          5.387300e+10  5.190300e+10  4.638600e+10
# Other Current Liab                5.344200e+10  5.010200e+10  5.502900e+10
# Total Assets                      9.881750e+11  9.492610e+11  8.521950e+11
# Common Stock                      1.359900e+10  1.343000e+10  1.297100e+10
# Other Current Assets              2.530900e+10  2.686200e+10  3.268400e+10
# Retained Earnings                 3.549700e+10  3.074500e+10  2.872500e+10
# Other Liab                        4.837000e+09  4.777000e+09  1.165200e+10
# Good Will                         5.378000e+09  6.535000e+09  6.340000e+09
# Treasury Stock                    4.464000e+09  7.426000e+09  4.387000e+09
# Other Assets                      4.649850e+11  4.535680e+11  4.323130e+11
# Cash                              9.315100e+10  5.729700e+10  4.690800e+10
# Total Current Liabilities         8.716170e+11  8.310250e+11  7.323240e+11
# Deferred Long Term Asset Charges  1.287000e+09  1.473000e+09  1.568000e+09
# Short Long Term Debt              1.019750e+11  9.420500e+10  8.913200e+10
# Other Stockholder Equity          4.464000e+09  7.426000e+09  4.387000e+09
# Property Plant Equipment          4.869000e+09  4.860000e+09  2.925000e+09
# Total Current Assets              3.822390e+11  3.454300e+11  3.046580e+11
# Long Term Investments             1.284380e+11  1.364260e+11  1.035350e+11
# Net Tangible Assets               4.622900e+10  4.292600e+10  3.762200e+10
# Short Term Investments            1.156850e+11  1.209130e+11  1.119910e+11
# Net Receivables                   6.959000e+09  5.682000e+09  4.973000e+09
# Long Term Debt                    5.145500e+10  5.445700e+10  5.714300e+10
# Inventory                         1.100000e+07  2.700000e+07  5.500000e+07
# Accounts Payable                  6.577460e+11  6.341850e+11  5.417960e+11
#
#                                     2018-10-31
# Intangible Assets                 2.272000e+09
# Capital Surplus                   3.000000e+08
# Total Liab                        7.275720e+11
# Total Stockholder Equity          4.138100e+10
# Other Current Liab                5.290500e+10
# Total Assets                      7.732930e+11
# Common Stock                      1.292900e+10
# Other Current Assets              2.532300e+10
# Retained Earnings                 2.585000e+10
# Other Liab                        1.247100e+10
# Good Will                         6.373000e+09
# Treasury Stock                    2.302000e+09
# Other Assets                      3.910840e+11
# Cash                              4.048700e+10
# Total Current Liabilities         6.619260e+11
# Deferred Long Term Asset Charges  2.039000e+09
# Short Long Term Debt              3.703000e+09
# Other Stockholder Equity          2.302000e+09
# Property Plant Equipment          2.923000e+09
# Total Current Assets              2.894030e+11
# Long Term Investments             8.123800e+10
# Net Tangible Assets               3.273600e+10
# Short Term Investments            9.335600e+10
# Net Receivables                   5.060000e+09
# Long Term Debt                    5.317500e+10
# Inventory                         5.800000e+07
# Accounts Payable                  4.948590e+11

# %%
tri.balance_sheet
# Out:
#                                     2021-12-31    2020-12-31    2019-12-31  \
# Intangible Assets                 4.153000e+09  4.257000e+09  4.418000e+09
# Total Liab                        8.315000e+09  7.901000e+09  7.735000e+09
# Total Stockholder Equity          1.383400e+10  9.870000e+09  9.450000e+09
# Other Current Liab                2.581000e+09  1.545000e+09  1.444000e+09
# Total Assets                      2.214900e+10  1.788100e+10  1.729500e+10
# Common Stock                      5.496000e+09  3.609000e+09  3.466000e+09
# Retained Earnings                 9.149000e+09  5.211000e+09  4.965000e+09
# Other Liab                        1.948000e+09  1.254000e+09  1.587000e+09
# Good Will                         5.940000e+09  5.976000e+09  5.853000e+09
# Treasury Stock                   -8.110000e+08 -6.890000e+08 -7.820000e+08
# Other Assets                      2.365000e+09  1.794000e+09  1.689000e+09
# Cash                              7.780000e+08  1.787000e+09  8.250000e+08
# Total Current Liabilities         2.581000e+09  2.652000e+09  3.219000e+09
# Deferred Long Term Asset Charges  1.139000e+09  1.204000e+09  1.176000e+09
# Other Stockholder Equity         -8.110000e+08 -6.890000e+08 -7.820000e+08
# Property Plant Equipment          5.020000e+08  5.450000e+08  6.150000e+08
# Total Current Assets              2.453000e+09  3.975000e+09  3.071000e+09
# Long Term Investments             6.736000e+09  1.334000e+09  1.649000e+09
# Net Tangible Assets               3.741000e+09 -3.630000e+08 -8.210000e+08
# Short Term Investments            1.080000e+08  6.120000e+08  5.330000e+08
# Net Receivables                   1.057000e+09  1.216000e+09  1.239000e+09
# Long Term Debt                    3.786000e+09  3.772000e+09  2.676000e+09
# Capital Surplus                            NaN  1.739000e+09  1.801000e+09
# Deferred Long Term Liab                    NaN  1.050000e+08  8.200000e+07
# Other Current Assets                       NaN  2.080000e+08  3.210000e+08
# Inventory                                  NaN  2.600000e+07  2.300000e+07
# Accounts Payable                           NaN  2.170000e+08  2.650000e+08
# Short Long Term Debt                       NaN           NaN  6.400000e+08
#
#                                     2018-12-31
# Intangible Assets                 4.232000e+09
# Total Liab                        7.808000e+09
# Total Stockholder Equity          9.100000e+09
# Other Current Liab                1.471000e+09
# Total Assets                      1.701800e+10
# Common Stock                      3.333000e+09
# Retained Earnings                 4.739000e+09
# Other Liab                        1.828000e+09
# Good Will                         5.076000e+09
# Treasury Stock                   -8.770000e+08
# Other Assets                      4.770000e+08
# Cash                              2.706000e+09
# Total Current Liabilities         2.691000e+09
# Deferred Long Term Asset Charges  3.100000e+07
# Other Stockholder Equity         -8.770000e+08
# Property Plant Equipment          4.730000e+08
# Total Current Assets              4.521000e+09
# Long Term Investments             2.239000e+09
# Net Tangible Assets              -2.080000e+08
# Short Term Investments            7.600000e+07
# Net Receivables                   1.373000e+09
# Long Term Debt                    3.289000e+09
# Capital Surplus                   1.905000e+09
# Deferred Long Term Liab           8.200000e+07
# Other Current Assets              1.680000e+08
# Inventory                         3.300000e+07
# Accounts Payable                  3.260000e+08
# Short Long Term Debt              3.000000e+06

# %%
bmo.news
# Out:
# [{'uuid': '189ce029-ef5b-3444-89b2-8359741d255f',
#   'title': 'IR Appoints Stuart Matthewman as Chief Marketing Officer',
#   'publisher': 'PR Newswire',
#   'link': 'https://finance.yahoo.com/news/ir-appoints-stuart-matthewman-chief-013600315.html',
#   'providerPublishTime': 1646789760,
#   'type': 'STORY'},
#  {'uuid': '0ea54409-c8f0-3507-953d-9b63cc6e4136',
#   'title': 'Colombia launches offshore wind-energy plan, announces first project',
#   'publisher': 'Reuters',
#   'link': 'https://finance.yahoo.com/news/colombia-launches-offshore-wind-energy-013233643.html',
#   'providerPublishTime': 1646789553,
#   'type': 'STORY'},
#  {'uuid': '6d7e706e-441d-3eaf-8746-7dc8a71f77c9',
#   'title': 'UPDATE 1-Japan likely to avert stagflation, says senior central banker',
#   'publisher': 'Reuters',
#   'link': 'https://finance.yahoo.com/news/1-japan-likely-avert-stagflation-013136734.html',
#   'providerPublishTime': 1646789496,
#   'type': 'STORY'},
#  {'uuid': 'f107b7d5-7bbe-3d47-b7cd-ddae0e91500c',
#   'title': 'Fluent, Inc (FLNT) Q4 2021 Earnings Call Transcript',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/f107b7d5-7bbe-3d47-b7cd-ddae0e91500c/fluent%2C-inc-%28flnt%29-q4-2021.html',
#   'providerPublishTime': 1646789428,
#   'type': 'STORY'},
#  {'uuid': 'bf21d5cd-221f-3284-880b-40e4601ce2bd',
#   'title': 'Yext, Inc. (YEXT) Q4 2022 Earnings Call Transcript',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/bf21d5cd-221f-3284-880b-40e4601ce2bd/yext%2C-inc.-%28yext%29-q4-2022.html',
#   'providerPublishTime': 1646789425,
#   'type': 'STORY'},
#  {'uuid': '327ec99a-9f34-36a9-b096-65d472db4149',
#   'title': 'Legend Power(R) Announces Issuance of Equity Incentives',
#   'publisher': 'ACCESSWIRE',
#   'link': 'https://finance.yahoo.com/news/legend-power-r-announces-issuance-013000826.html',
#   'providerPublishTime': 1646789400,
#   'type': 'STORY'},
#  {'uuid': 'a001576b-7e0a-3208-a83f-bb3c6cb389dc',
#   'title': 'USD 2.31 Bn growth opportunity in Inverter Duty Motor Market | Research report highlights North America as major market | Technavio',
#   'publisher': 'PR Newswire',
#   'link': 'https://finance.yahoo.com/news/usd-2-31-bn-growth-013000661.html',
#   'providerPublishTime': 1646789400,
#   'type': 'STORY'},
#  {'uuid': 'b5952abc-c8df-35d6-aa53-321cac872028',
#   'title': 'Australia Rate Hike Later This Year ‘Plausible,’ Lowe Says',
#   'publisher': 'Bloomberg',
#   'link': 'https://finance.yahoo.com/news/rba-lowe-says-interest-rate-222000842.html',
#   'providerPublishTime': 1646789308,
#   'type': 'STORY'}]

# %%
tri.news
# Out:
# [{'uuid': '189ce029-ef5b-3444-89b2-8359741d255f',
#   'title': 'IR Appoints Stuart Matthewman as Chief Marketing Officer',
#   'publisher': 'PR Newswire',
#   'link': 'https://finance.yahoo.com/news/ir-appoints-stuart-matthewman-chief-013600315.html',
#   'providerPublishTime': 1646789760,
#   'type': 'STORY'},
#  {'uuid': '0ea54409-c8f0-3507-953d-9b63cc6e4136',
#   'title': 'Colombia launches offshore wind-energy plan, announces first project',
#   'publisher': 'Reuters',
#   'link': 'https://finance.yahoo.com/news/colombia-launches-offshore-wind-energy-013233643.html',
#   'providerPublishTime': 1646789553,
#   'type': 'STORY'},
#  {'uuid': '6d7e706e-441d-3eaf-8746-7dc8a71f77c9',
#   'title': 'UPDATE 1-Japan likely to avert stagflation, says senior central banker',
#   'publisher': 'Reuters',
#   'link': 'https://finance.yahoo.com/news/1-japan-likely-avert-stagflation-013136734.html',
#   'providerPublishTime': 1646789496,
#   'type': 'STORY'},
#  {'uuid': 'f107b7d5-7bbe-3d47-b7cd-ddae0e91500c',
#   'title': 'Fluent, Inc (FLNT) Q4 2021 Earnings Call Transcript',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/f107b7d5-7bbe-3d47-b7cd-ddae0e91500c/fluent%2C-inc-%28flnt%29-q4-2021.html',
#   'providerPublishTime': 1646789428,
#   'type': 'STORY'},
#  {'uuid': 'bf21d5cd-221f-3284-880b-40e4601ce2bd',
#   'title': 'Yext, Inc. (YEXT) Q4 2022 Earnings Call Transcript',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/bf21d5cd-221f-3284-880b-40e4601ce2bd/yext%2C-inc.-%28yext%29-q4-2022.html',
#   'providerPublishTime': 1646789425,
#   'type': 'STORY'},
#  {'uuid': '327ec99a-9f34-36a9-b096-65d472db4149',
#   'title': 'Legend Power(R) Announces Issuance of Equity Incentives',
#   'publisher': 'ACCESSWIRE',
#   'link': 'https://finance.yahoo.com/news/legend-power-r-announces-issuance-013000826.html',
#   'providerPublishTime': 1646789400,
#   'type': 'STORY'},
#  {'uuid': 'a001576b-7e0a-3208-a83f-bb3c6cb389dc',
#   'title': 'USD 2.31 Bn growth opportunity in Inverter Duty Motor Market | Research report highlights North America as major market | Technavio',
#   'publisher': 'PR Newswire',
#   'link': 'https://finance.yahoo.com/news/usd-2-31-bn-growth-013000661.html',
#   'providerPublishTime': 1646789400,
#   'type': 'STORY'},
#  {'uuid': 'b5952abc-c8df-35d6-aa53-321cac872028',
#   'title': 'Australia Rate Hike Later This Year ‘Plausible,’ Lowe Says',
#   'publisher': 'Bloomberg',
#   'link': 'https://finance.yahoo.com/news/rba-lowe-says-interest-rate-222000842.html',
#   'providerPublishTime': 1646789308,
#   'type': 'STORY'}]

# %%
bmo.recommendations
# Out:
#                                   Firm        To Grade      From Grade Action
# Date
# 2012-02-23 06:01:00      Credit Suisse      Outperform                     up
# 2012-08-07 13:32:00           Barclays     Underweight    Equal-Weight   down
# 2012-08-28 07:48:00    Stifel Nicolaus            Hold                   init
# 2012-08-29 07:43:00         Desjardins             Buy            Hold     up
# 2012-08-29 08:03:00        BMO Capital  Market Perform                   main
# 2013-02-11 12:09:40           Barclays     Underweight                   main
# 2013-02-27 07:38:06        BMO Capital  Market Perform                   main
# 2013-02-27 08:24:30          Citigroup             Buy                   init
# 2013-05-14 11:52:25     Morgan Stanley     Underweight    Equal-Weight   down
# 2013-05-30 08:38:27        BMO Capital  Market Perform                   main
# 2013-08-28 07:15:09        BMO Capital  Market Perform                   main
# 2013-10-17 16:00:00      TD Securities            Hold                   init
# 2013-11-21 13:21:39           Barclays     Underweight                   main
# 2014-05-01 08:00:00  Canaccord Genuity            Hold                   init
# 2014-08-19 09:00:00           Barclays    Equal-Weight                   main
# 2014-08-27 07:42:52      TD Securities             Buy            Hold     up
# 2014-10-09 16:00:00  Canaccord Genuity             Buy            Hold     up
# 2014-12-01 00:00:00          Citigroup         Neutral             Buy   down
# 2015-02-24 09:00:00          Citigroup         Neutral                   main
# 2015-02-27 09:00:00          Citigroup         Neutral                   main
# 2015-12-02 11:11:50      TD Securities             Buy            Hold     up
# 2015-12-17 06:05:36      Credit Suisse      Outperform                   main
# 2016-03-08 06:33:30      Credit Suisse         Neutral      Outperform   down
# 2016-05-26 07:26:51  Canaccord Genuity            Hold             Buy   down
# 2016-05-26 07:50:46         Scotiabank  Sector Perform      Outperform   down
# 2016-05-26 07:51:08      TD Securities            Hold             Buy   down
# 2016-06-09 16:10:01           Rafferty             Buy            Hold     up
# 2016-09-21 07:57:33             Dundee         Neutral                   init
# 2016-10-04 14:31:30      Credit Suisse    Underperform         Neutral   down
# 2016-10-05 11:47:14      Credit Suisse    Underperform         Neutral   down
# 2016-11-23 12:49:48      Credit Suisse         Neutral    Underperform     up
# 2016-12-07 18:28:03  Canaccord Genuity             Buy            Hold     up
# 2017-05-18 16:20:52          Citigroup             Buy         Neutral     up
# 2017-05-23 11:35:45           Barclays    Equal-Weight     Underweight     up
# 2018-02-15 13:56:03          Macquarie      Outperform         Neutral     up
# 2018-07-18 11:26:15        RBC Capital      Outperform  Sector Perform     up
# 2018-08-29 12:47:50  Canaccord Genuity             Buy            Hold     up
# 2019-01-28 13:43:45    Bank of America    Underperform         Neutral   down
# 2020-02-26 17:32:48  B of A Securities    Underperform                   main
# 2020-05-11 15:23:11           Barclays    Equal-Weight                   main
# 2020-05-13 12:53:49  B of A Securities    Underperform                   main
# 2020-12-02 15:56:21      Credit Suisse         Neutral                   main
# 2021-02-24 11:11:53      Credit Suisse      Outperform         Neutral     up
# 2021-02-24 16:44:08  Canaccord Genuity             Buy                   main
# 2021-03-02 16:52:56  B of A Securities             Buy         Neutral     up

# %%
tri.recommendations
# Out:
#                                Firm        To Grade    From Grade Action
# Date
# 2020-11-04 15:32:06      ScotiaBank  Sector Perform                 main
# 2020-11-25 09:36:35        Barclays    Equal-Weight                 main
# 2020-11-25 09:36:35       Jefferies            Hold                 init
# 2020-11-25 09:36:35   Credit Suisse      Outperform                 main
# 2020-11-25 09:36:35   Deutsche Bank            Hold                 main
# ...                             ...             ...           ...    ...
# 2021-02-24 13:52:53  Morgan Stanley    Equal-Weight                 main
# 2021-02-24 15:14:21      ScotiaBank  Sector Perform                 main
# 2021-03-17 11:40:01  Morgan Stanley    Equal-Weight                 main
# 2021-05-05 10:45:22            CIBC         Neutral  Outperformer   down
# 2021-05-05 12:55:39  Morgan Stanley    Equal-Weight                 main
#
# [83 rows x 4 columns]
