# %%
# Import all libraries and dependencies

import datetime
import pandas as pd
import yfinance as yf
from path import Path

# %%
#Define the tickers to download data of the stocks.
tickers = ["SHOP.TO", "CIX.TO", "L.TO"]

# Fetch tickers data from 1/1/2019 until 3/3/2022.
start_date = datetime.date(2019,1,1)
end_date = datetime.date(2022,3,3)
interval = '1d'
period = round((end_date - start_date).days/365,0)
if interval == "1d":
    annual_interval = 252

# %%
# Use yfinance to download the data
yf.Tickers(tickers)
stock_data = yf.download(tickers, start = start_date, end = end_date, interval = interval)

# Check the data type
type(stock_data)
# Out:
# [*********************100%***********************]  3 of 3 completed
# pandas.core.frame.DataFrame

# %%
# Review data
stock_data
# Out:
#             Adj Close                              Close              \
#                CIX.TO        L.TO     SHOP.TO     CIX.TO        L.TO
# Date
# 2019-01-02  15.299250   57.818455  187.110001  17.129999   61.049999
# 2019-01-03  15.451079   57.458569  174.910004  17.299999   60.669998
# 2019-01-04  15.486807   57.581688  184.979996  17.340000   60.799999
# 2019-01-07  15.611842   58.121513  191.910004  17.480000   61.369999
# 2019-01-08  15.745813   58.576107  193.210007  17.629999   61.849998
# ...               ...         ...         ...        ...         ...
# 2022-02-24  20.430000  101.059998  850.619995  20.430000  101.059998
# 2022-02-25  20.930000  100.949997  859.950012  20.930000  100.949997
# 2022-02-28  20.750000   98.870003  879.919983  20.750000   98.870003
# 2022-03-01  20.410000   98.019997  858.330017  20.410000   98.019997
# 2022-03-02  20.969999   99.489998  833.859985  20.969999   99.489998
#
#                              High                                Low  \
#                SHOP.TO     CIX.TO        L.TO     SHOP.TO     CIX.TO
# Date
# 2019-01-02  187.110001  17.350000   61.799999  188.990005  16.920000
# 2019-01-03  174.910004  17.420000   61.110001  184.839996  16.930000
# 2019-01-04  184.979996  17.830000   61.290001  186.750000  17.280001
# 2019-01-07  191.910004  17.520000   61.599998  193.899994  17.200001
# 2019-01-08  193.210007  17.780001   62.090000  199.089996  17.450001
# ...                ...        ...         ...         ...        ...
# 2022-02-24  850.619995  20.600000  101.489998  855.239990  19.650000
# 2022-02-25  859.950012  21.000000  101.430000  875.000000  20.450001
# 2022-02-28  879.919983  20.980000  100.629997  890.369995  20.420000
# 2022-03-01  858.330017  20.850000   99.639999  900.150024  20.219999
# 2022-03-02  833.859985  21.059999   99.650002  862.140015  20.420000
#
#                                         Open                          Volume  \
#                  L.TO     SHOP.TO     CIX.TO       L.TO     SHOP.TO   CIX.TO
# Date
# 2019-01-02  60.450001  179.139999  17.129999  60.970001  182.020004   379300
# 2019-01-03  60.369999  174.589996  17.100000  60.770000  184.839996   575100
# 2019-01-04  60.509998  179.149994  17.510000  60.930000  180.000000   526900
# 2019-01-07  60.470001  185.199997  17.389999  61.000000  186.860001   382500
# 2019-01-08  61.310001  191.679993  17.610001  61.549999  195.000000   384800
# ...               ...         ...        ...        ...         ...      ...
# 2022-02-24  95.010002  752.000000  19.990000  95.120003  752.000000  1290700
# 2022-02-25  97.370003  821.099976  20.680000  99.570000  864.900024   710700
# 2022-02-28  98.449997  848.590027  20.700001  99.919998  863.510010  1152000
# 2022-03-01  97.650002  855.000000  20.850000  98.839996  874.750000   878300
# 2022-03-02  98.019997  807.270020  20.420000  98.129997  862.140015   825700
#
#
#                L.TO SHOP.TO
# Date
# 2019-01-02   626700  301600
# 2019-01-03   617800  315700
# 2019-01-04   444100  268400
# 2019-01-07   724700  280400
# 2019-01-08   601100  276400
# ...             ...     ...
# 2022-02-24   694500  356800
# 2022-02-25   810300  371700
# 2022-02-28  1081900  373900
# 2022-03-01   497200  268200
# 2022-03-02   439000  291400
#
# [795 rows x 18 columns]

# %%
# Select closing prices and volume only
price_and_volume = stock_data[["Close", "Volume"]]
price_and_volume.head()
# Out:
#                 Close                         Volume
#                CIX.TO       L.TO     SHOP.TO  CIX.TO    L.TO SHOP.TO
# Date
# 2019-01-02  17.129999  61.049999  187.110001  379300  626700  301600
# 2019-01-03  17.299999  60.669998  174.910004  575100  617800  315700
# 2019-01-04  17.340000  60.799999  184.979996  526900  444100  268400
# 2019-01-07  17.480000  61.369999  191.910004  382500  724700  280400
# 2019-01-08  17.629999  61.849998  193.210007  384800  601100  276400

# %%
price_and_volume.tail()
# Out:
#                 Close                           Volume
#                CIX.TO        L.TO     SHOP.TO   CIX.TO     L.TO SHOP.TO
# Date
# 2022-02-24  20.430000  101.059998  850.619995  1290700   694500  356800
# 2022-02-25  20.930000  100.949997  859.950012   710700   810300  371700
# 2022-02-28  20.750000   98.870003  879.919983  1152000  1081900  373900
# 2022-03-01  20.410000   98.019997  858.330017   878300   497200  268200
# 2022-03-02  20.969999   99.489998  833.859985   825700   439000  291400

# %%
# Count nulls. If there are any nulls, drop them.
price_and_volume.isnull().sum()
# Out:
# Close   CIX.TO     0
#         L.TO       0
#         SHOP.TO    0
# Volume  CIX.TO     0
#         L.TO       0
#         SHOP.TO    0
# dtype: int64

# %%
# Drop the nulls.
price_and_volume = price_and_volume.dropna()

# %%
# Check that nulls were successfully dropped.
price_and_volume.isnull().sum()
# Out:
# Close   CIX.TO     0
#         L.TO       0
#         SHOP.TO    0
# Volume  CIX.TO     0
#         L.TO       0
#         SHOP.TO    0
# dtype: int64

# %%
# Check for duplicates
price_and_volume.duplicated().sum()
# Out:
# 0

# %%
# Describe data
price_and_volume.describe()
# Out:
#             Close                                 Volume                \
#            CIX.TO        L.TO      SHOP.TO        CIX.TO          L.TO
# count  795.000000  795.000000   795.000000  7.950000e+02  7.950000e+02
# mean    20.245774   73.512113  1048.418064  7.014425e+05  5.959356e+05
# std      3.694227   10.941982   577.018721  7.641540e+05  3.470714e+05
# min     11.170000   59.470001   174.910004  5.170000e+04  1.029000e+05
# 25%     17.785001   66.669998   443.279999  3.969500e+05  3.759000e+05
# 50%     19.260000   69.610001  1187.979980  5.698000e+05  5.082000e+05
# 75%     22.550000   74.879997  1484.979980  8.123000e+05  7.121500e+05
# max     30.400000  104.419998  2139.820068  1.814350e+07  3.783900e+06
#
#
#             SHOP.TO
# count  7.950000e+02
# mean   2.516079e+05
# std    2.375044e+05
# min    2.150000e+04
# 25%    1.564000e+05
# 50%    2.180000e+05
# 75%    3.074000e+05
# max    5.829400e+06

# %%
# Check if closing price and volume are floats 
price_and_volume.dtypes
# Out:
# Close   CIX.TO     float64
#         L.TO       float64
#         SHOP.TO    float64
# Volume  CIX.TO       int64
#         L.TO         int64
#         SHOP.TO      int64
# dtype: object

# %%
# Assign closing price to its own DataFrame
close_price = price_and_volume[["Close"]]
close_price.head()
# Out:
#                 Close
#                CIX.TO       L.TO     SHOP.TO
# Date
# 2019-01-02  17.129999  61.049999  187.110001
# 2019-01-03  17.299999  60.669998  174.910004
# 2019-01-04  17.340000  60.799999  184.979996
# 2019-01-07  17.480000  61.369999  191.910004
# 2019-01-08  17.629999  61.849998  193.210007

# %%
# Assign volume to its own DataFrame
volume = price_and_volume[["Volume"]]
volume.head()
# Out:
#             Volume
#             CIX.TO    L.TO SHOP.TO
# Date
# 2019-01-02  379300  626700  301600
# 2019-01-03  575100  617800  315700
# 2019-01-04  526900  444100  268400
# 2019-01-07  382500  724700  280400
# 2019-01-08  384800  601100  276400

# %%
# Plot the closing prices
close_price.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Save to CSV
file_path = Path("Resources/stocks_1.csv")
price_and_volume.to_csv(file_path, index=False, encoding='utf-8-sig')
